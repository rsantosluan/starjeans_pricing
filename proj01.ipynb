# %% [markdown]
# ### 1. Imports

# %%
from IPython.display import Image

# %% [markdown]
# ### 2. Método SAPE

# %% [markdown]
# #### 2.1 Definição geral

# %% [markdown]
# <b> Problema de Negócio</b> <br>
# - Qual o melho preço de venda para calças;
#
# <b> Saída: (Entregável)</b> <br>
# 1. Resposta para a pergunta:
#     - Mediana dos preço das concorrentes.<br>
# 2. Formato da entrega;
#     -Tabela ou gráfico.     <br>
# 3. Local da entrega
#         - App Streamlit.<br>
#
# <b> Processo:</b> <br>
# 1. Definição do escopo de construção do cáculo de média ou mediana;
#     - Realizar<br>
# 2. Definir o formato de entrega (Visualização, Tabela, Frase);
#     - Gráfico de barras com a mediana dos preços dos produtos por: preço, tipo e cor nos últimos 30 dias.
#     - Tabela com as seguintes colunas: id | prod_name | prod_type | prod_color | prod_price.
#     - Definição do schema: colunas e o tipo.
#     - Definição da infraestrutura de armazenamento (SQLite3).
#     - Design do ETL (Scripts de extração, transformação e carga dos dados).
#     - Planejamento do agendamento dos scripts.
#     - Criar as visualizações.
#     - Entrega do produto final.
# 3. Decidir o local de entrega (Power Bi, Telegram, E-mail, Streamlit, Intranet);
#     - App no Streamlit
#
# <b> Entrada de Dados</b> <br>
# 1. Fonte de coleta dos dados;
#     - Site da H&M:   https://www2.hm.com/en_us/men/products/jeans.html
#     - Site da Macys: https://www.macys.com/shop/mens-clothing/mens-jeans
# 2. Ferramentas;
#     - Python 3.10.4
#     - Libs de Webscrapping (BS4, Selenium)
#     - VSCode
#     - Contjob, Airflow
#     - Streamlit

# %% [markdown]
# #### 2.2 Definição aplicada

# %% [markdown]
# 1. Qual o melhor preço de vendas para as calças?
# 2. Quantos tipos de calças e quais cores para o produto inicial?
# 3. Quais as matérias-primas necessárias para confeccionar as calças?
#
# <b> Saída:</b>
# 1. Resposta para a pergunta:
#     - Frente análise de mercado onde a variação do preço é muito mais emocional do que racional, será usado um modelo conservador e muito simples: A mediana dos valores dos produtos do site dos concorrentes;
# 2. Formato:
#     -Tabela ou gráfico;
# 3. Local:
#     - App no Streamlit;
#
# <b> Processo: </b>
# 1. Passo a passo para efetuar o cálculo da resposta:
#     - Mediana do preço por categoria e tipo;
# 2. Como será o gráfico ou tabela
#     - Simulação da tabela final;
# 3. Como será o local de entrega
#     - Criação de Dashboard no Streamlit e publicação no Heroku;
#
# <b> Entradas:</b>
# 1. Site da H&M:   https://www2.hm.com/en_us/men/products/jeans.html
# 2. Site da Macys: https://www.macys.com/shop/mens-clothing/mens-jeans

# %% [markdown]
# ### 3. Método Cíclico

# %% [markdown]
# #### 3.1 Questão de negócio

# %% [markdown]
#     A empresa Star Jeans! Eduardo e Marcelo são dois brasileiros, amigos e sócios de empreendi-
#     mento. Depois de vários negócio bem sucedidos, eles estão planejando entrar no mercado de moda
#     dos USA como um modelo de negócio do tipo E-commerce.
#     A idéia inicial é entrar no mercado com apenas um produto e para um público específico, no caso
#     o produto seria calças Jenas para o público masculino. O objetivo é manter o custo de operação
#     baixo e escalar a medida que forem conseguindo clientes.
#     Porém, mesmo com o produto de entrada e a audiência definidos, os dois sócios não tem experiência
#     nesse mercado de moda e portanto não sabem definir coisas básicas como preço, o tipo de calça e
#     o material para a fabricação de cada peça.
#     Assim, os dois sócios contrataram uma consultoria de Ciência de Dados para responder as seguintes
#     perguntas: 1. Qual o melhor preço de venda para as calças? 2. Quantos tipos de calças e suas
#     cores para o produto inicial? 3. Quais as matérias-prima necessárias para confeccionar as calças?
#     As principais concorrentes da empresa Start Jeans são as americadas H&M e Macys.

# %% [markdown]
# #### 3.2 Cícolo do CRISP

# %%
Image('img/CRISP_DM.png', width=800)
